# %% [markdown]
# # Moving Average (MA) Model

# %%
import pandas as pd

sp500 = pd.read_csv("./S&P500.csv")
sp500
# Out:
#            Date    SP500  Dividend  Earnings  Consumer Price Index  \
# 0      1/1/1900     6.10      0.22      0.48                  7.90
# 1      1/2/1900     6.21      0.23      0.48                  7.99
# 2      1/3/1900     6.26      0.23      0.48                  7.99
# 3      1/4/1900     6.34      0.24      0.48                  7.99
# 4      1/5/1900     6.04      0.25      0.48                  7.80
# ...         ...      ...       ...       ...                   ...
# 1415  1/12/2017  2664.34     48.93    109.88                246.52
# 1416   1/1/2018  2789.80     49.29       NaN                247.87
# 1417   1/2/2018  2705.16     49.64       NaN                248.99
# 1418   1/3/2018  2702.77     50.00       NaN                249.55
# 1419   1/4/2018  2642.19       NaN       NaN                249.84
#
#       Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10
# 0                   3.15      192.98           6.88          15.19  18.67
# ...

# %% [markdown]
# ## Simple Moving Average
#
# $$
# \frac{a_1,a_2,a_3, ..., a_n}{n}
# $$

# %%
# Average over 3 Months
sp500["SP500_SMA_3"] = sp500.iloc[:,1].rolling(window=3).mean()
sp500[["Date", "SP500", "SP500_SMA_3"]]
# Out:
#            Date    SP500  SP500_SMA_3
# 0      1/1/1900     6.10          NaN
# 1      1/2/1900     6.21          NaN
# 2      1/3/1900     6.26     6.190000
# 3      1/4/1900     6.34     6.270000
# 4      1/5/1900     6.04     6.213333
# ...         ...      ...          ...
# 1415  1/12/2017  2664.34  2604.983333
# 1416   1/1/2018  2789.80  2682.583333
# 1417   1/2/2018  2705.16  2719.766667
# 1418   1/3/2018  2702.77  2732.576667
# 1419   1/4/2018  2642.19  2683.373333
#
# [1420 rows x 3 columns]

# %%
# Average of 30 Months 
sp500["SP500_SMA_30"] = sp500.iloc[:,1].rolling(window=30).mean()
sp500[["Date", "SP500", "SP500_SMA_3","SP500_SMA_30"]]
# Out:
#            Date    SP500  SP500_SMA_3  SP500_SMA_30
# 0      1/1/1900     6.10          NaN           NaN
# 1      1/2/1900     6.21          NaN           NaN
# 2      1/3/1900     6.26     6.190000           NaN
# 3      1/4/1900     6.34     6.270000           NaN
# 4      1/5/1900     6.04     6.213333           NaN
# ...         ...      ...          ...           ...
# 1415  1/12/2017  2664.34  2604.983333   2223.955667
# 1416   1/1/2018  2789.80  2682.583333   2247.144333
# 1417   1/2/2018  2705.16  2719.766667   2269.320667
# 1418   1/3/2018  2702.77  2732.576667   2294.599333
# 1419   1/4/2018  2642.19  2683.373333   2315.178667
#
# [1420 rows x 4 columns]

# %% [markdown]
# ## Exponential Moving Average
#
# EMA = Closing Price x multiplier + EMA(Previous Day) x (1 - multiplier)
#
# - Pandas has the `ewm()` function for EMA
# - The span, $\alpha$, formula is the formula for the multiplier when the smoothing factor is 2
#
# $$
# \alpha = \frac{2}{observations + 1}
# $$
#
# - When `adjust = False`, the exponentially weighted function is calculated recursively
#
# $$
# y_0 = x_0
# $$
# $$
# y_t = \alpha x_t + y_{t-1} (1 - \alpha)
# $$

# %%
sp500["SP500_EMA_30"] = sp500.iloc[:,1].ewm(span=30, adjust=False).mean()

multiplier = 2 / (30 + 1)
sp500.loc[0, "SP500_EMA_30_Man"] = sp500.loc[0,"SP500"]

for i in range(1, len(sp500)):
    sp500.loc[i, "SP500_EMA_30_Man"] = (sp500.loc[i,"SP500"] * multiplier) + (sp500.loc[i - 1,"SP500_EMA_30_Man"] * (1 - multiplier)) 

sp500[["Date", "SP500", "SP500_SMA_3","SP500_SMA_30", "SP500_EMA_30", "SP500_EMA_30_Man"]]
# Out:
#            Date    SP500  SP500_SMA_3  SP500_SMA_30  SP500_EMA_30  \
# 0      1/1/1900     6.10          NaN           NaN      6.100000
# 1      1/2/1900     6.21          NaN           NaN      6.107097
# 2      1/3/1900     6.26     6.190000           NaN      6.116961
# 3      1/4/1900     6.34     6.270000           NaN      6.131351
# 4      1/5/1900     6.04     6.213333           NaN      6.125457
# ...         ...      ...          ...           ...           ...
# 1415  1/12/2017  2664.34  2604.983333   2223.955667   2271.796321
# 1416   1/1/2018  2789.80  2682.583333   2247.144333   2305.215913
# 1417   1/2/2018  2705.16  2719.766667   2269.320667   2331.018758
# 1418   1/3/2018  2702.77  2732.576667   2294.599333   2355.002709
# 1419   1/4/2018  2642.19  2683.373333   2315.178667   2373.530921
#
#       SP500_EMA_30_Man
# 0             6.100000
# 1             6.107097
# 2             6.116961
# 3             6.131351
# 4             6.125457
# ...                ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=[18,12])
plt.grid(True)
plt.plot(sp500["SP500"], label = "Original")
plt.plot(sp500["SP500_SMA_3"], label = "SP500_SMA_3")
plt.plot(sp500["SP500_SMA_30"], label = "SP500_SMA_30")
plt.plot(sp500["SP500_EMA_30"], label = "SP500_EMA_30")
plt.legend(loc=2)
